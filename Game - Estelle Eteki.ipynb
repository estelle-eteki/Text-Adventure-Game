# %%
"""
DocString:
    
    A) Introduction:
    
    As you may have guessed, this is WHO WANTS TO BE A MILLIONAIRE. The game 
    has been inspired by 'Who wants to be a millionaire and the French 
    tv show 'Tout le monde veut prendre sa place' meaning 'Everyone wants to 
    take its place'. This game consists of four rounds requiring general 
    knwoledge, history, culture and well luck. Each round consists of choosing 
    the right answer to the question between propositions. 
    
    Round 1: Two propositions
    Round 2: Three propositions
    Round 3: Four propositions
    Round 4: Four propositions
    
    The difficulty level of the questions increases each round.
    
    B) Known Bugs and/or Errors:
    None.


"""    
    
from sys import exit
from random import randint
    
    
def game_start():
    global host_name
    global country
    global food
    
    print("\nHello and welcome once to WHO WANT TO BE A MILLIONAIRE!!!\n")    
    input('<Press any key to continue>\n')
    
    print("My name is Estelle and  I'm hosting today's Who wants to be a millionaire. \n")       
    host_name = input('So, how am I calling you tonight ? \n')       
    host_name = host_name.capitalize()
    
    
    print(f"""We welcome our contestant {host_name} that will compete for the ultimate million dollar prize!
              Thank you for joining us.
              These are the rules of the game. In order to gain the prize, you need to reach 1,000,000 points
              and answer four questions.
              The first question gives you 1,000 points, the second 10,000 points, the third 100,000 and finally the last
              and fourth question 1,000,000 points and the million dollar.
              
              You should ONLY answer with the letter associated to the question.\n""")  
    
    input("<Press any key to continue")
    
    country = input("Before starting, where are you coming from?")
    country = country.capitalize()
    print(f""" Thank you very much.
               A lot of applause for {host_name} coming from {country} !""")
    
    print("\nSo What are your plans if you win the million dollar prize today ?")
    input(">")
    print("""\n Waouh ! That's really nice.
                So, let's start.""")
    
    input('<Press any key to continue>\n')

    round_1(-1) #A First round call
        
    
    # Round 1 Function
# This argument helps to identify in the loop whether it has been called for the first time or the user do not answer properly    
def round_1(x):
    
    score = 0
    
    # Questions, Answers and Correct answers list
    list_1 = ["What is the nationality of the athlete Usain Bolt?", "Who is the actual president of the United States?", 
              "Which of the following is not a type of pasta", "Which city contains Effeil Tower?", "Which state has cities named San Francisco and Hollywood", 
              "Which instrument does not have string?", "What product does Tesla produce?", "Which animal is not a primate?"]
    answer_A = ["A. Deutsch", "A. Donald Trump", "A. Fettucine", "A.  Paris",  "A. California", "A. Guitar",  "A. Hair dryers",  "A. Dolphin"]
    answer_B = ["B. Jamaican", "B. Bill Clinton", "B. Escargot", "B. New York City", "B.  Detroit", "B. Trombone", "B. Electric cars", "B. Gorilla"]
    correct_1 = ["b", "a", "b", "a", "a", "b", "b", "a"]

        
    i = 0
    while (i == 0): #The loop allow to stay in the round even providing an answer not a letter
          
        if x == -1: 
            x = randint(0, 7) # Choose an index to display the question randomly
            print("******************** FIRST ROUND ******************** \n\n")
           
        print(list_1[x] + "\n\t" + answer_A[x] + "\n\t" + answer_B[x] + "\n")
        answer = str(input("What is your answer ? \n\n"))
        answer = answer.lower()

        if answer not in correct_1: #Check if the user answers properly (either an 'a' or 'b')
            print("\n Please answer by the LETTER associated with the question!!! \n \n")
            
        else:
            if answer == correct_1[x]:
                print(f"""\n\n You provided a good answer.
                          Congratulations {host_name} you pass the first round.
                          Your score is 1,000 points !""")
                score = 1000
                i = -1
                input('<Press any key to continue>\n')
                round_2(-1) #Round 2 call
            else:
                fail(score)
                            
    
    # Round 2 Function
    ""
def round_2(x):
    
    score = 1000
    list_2 = ["Which of these are possible triggers for a psychotic episode?",  "The game of Mah-Jong originated in what country?", "What nationality is celebrated on St. Patrick's Day?", 
              "Between which two planets are asteroids chiefly found?", "What is singer Diana Ross's middle name?", 
              "Which team won the first two Super Bowls?", "Who wrote the novels that introduced the characters Hercule Poirot and Miss Jane Marple?"]
    answer_A = ["A. Taking drugs", "A. China", "A. Mexican", "A. Neptune and Pluto",  "A. Josephine",  "A. Green Bay Packers",  "A. Ruth Rendell"]
    answer_B = ["B. Going to school", "B. Russia", "B. Irish", "B. Saturn and Uranus", "B. Ernestine", "B. Chicago Bears", "B. Ellery Queen"]
    answer_C = ["C. Going shopping", "C. Japan", "C. American Indian", "C. Mars and Jupiter", "C. Libertine", "C. Minnesota Vikings", "C. Agatha Christie"]
    correct_2 = ["a", "a", "b", "c", "b", "a", "c"]


    i = 0
    while (i == 0):

        if x == -1:
            x = randint(0, 6)
            print("******************** SECOND ROUND ******************** \n\n")

        print(list_2[x] + "\n\t" + answer_A[x] + "\n\t" + answer_B[x] + "\n\t" + answer_C[x] + "\n")
        answer = input("What is your answer ? \n\n")
        answer = answer.lower()

        if answer not in correct_2:
            print("Please answer by the LETTER associated with the question!!! \n \n")
                        
        else:
            if answer == correct_2[x]:
                print(f"""\n\n You provided a good answer.
                          Congratulations {host_name} you pass the second round. 
                          Your score is 10,000 points !\n""")
                
                score = 10000
                i = -1
                input('<Press any key to continue>\n')
                round_34(-1, score) #Round 3 call
            else:
                fail(score)
                    
    
    # Round 3 & 4 Function
#the argument 'score' helps to know if the it is round 3 or round 4 which is called   
def round_34(x, score):
        
    # Round 3 function

    if score == 10000:

        list_3 = ["Which of these US presidents appeared on the television series ‘Laugh-In?’",  "The Earth is approximately how many miles away from the Sun?",  "Which insect shorted out the an early supercomputer and inspired the term ‘computer bug’",  
                  "Which of the following name does not have a chemical element named for him?", "Which of the following landlock countries in entirely contained within another country", "In the children’s book serie, where is Paddington originally from?", 
                  "Who is credited to invent the first mass computer?", "What letter must appear on all non-military aircrafts?", "During the World War II, US soldiers used the first commercial aerosols to hold what1?", "The US icon Uncle Sam was based on Samuel Wilson who worked during the War of 1812 as a what?"]
        answer_A = ["A. Lyndon Johnson", "A. 9.3 million",  "A. Moth", "A. Albert Einstein",  "A. Lesotho",  "A. India",  "A. Gotllieb Daimler",  "A. N",  "A. Cleaning fluid",  "A. Meat Inspector"]
        answer_B = ["B. Richard Nixon", "B. 39 million", "B. Fly", "B. Niels Bohr", "B. Burkina Faso", "B. Peru", "B. Elmer Sperry", "B. A", "B. Antiseptic", "B. Mail deliverer"]
        answer_C = ["C. Jimmy Carter", "C. 93 million", "C. Roach", "C. Isaac Newton", "C. Mongolia", "C. Canada", "C. Ferdinand Von Zeppelin", "C. U", "C. Insecticide", "C. Historian"]
        answer_D = ["D. Gerald Ford", "D. 193 million", "D. Japanese beetle", "D. Enrico Fermi", "D. Luxembourg", "D. Iceland", "D. Igor Sikorsky", "D. L", "D. Shaving cream", "D. Weapons Mechanic"]
        correct_3 = ["b", "c", "a", "c", "a", "b", "d", "a", "c", "a"]


        i = 0
        while (i == 0):

            if x == -1:
                x = randint(0, 9)
                print("******************** THIRD ROUND ******************** \n\n")

            print(list_3[x] + "\n\t" + answer_A[x] + "\n\t" + answer_B[x] + "\n\t" + answer_C[x] + "\n\t" + answer_D[x] + "\n")
            answer = input("What is your answer ? \n\n")
            answer = answer.lower()

            if answer not in correct_3:
                print("\n Please answer by the LETTER associated with the question!!! \n \n")
                
            else:
                if answer == correct_3[x]:
                    print(f"""\n You provided a good answer.
                               Congratulations {host_name} you pass the third round.
                               Your score is 100,000 points !""")
                    
                    score = 100000
                    i = -1
                    round_34(-1,score)

                else:
                    fail(score)
        
        # Round 4 function
        
    if score == 100000:

        list_4 = ["Who did artist Grant Wood use as the model for the farmer in his classic painting ‘American Gothic?’?", "Khrushchev's famous 1960 shoe-banging outburst at the UN was in response to a delegate from what nation?",  "The song “God Bless America” was originally written for what 1918 musical?", 
                  "Now used to refer to a cat, the word 'tabby' is derived from the name of a district of what world capital?", "Neurologists believe that the brain's medial ventral prefrontal cortex is activated when you do what?", "Compiled by Benjamin Franklin in 1737, ‘The Drinker's Dictionary’ included all but which of these synonyms for 'drunkenness'?", 
                  "What club did astronaut Alan Shepard use to make his famous golf shot on the moon?", "Famous pediatrician and author Dr. Benjamin Spock won an Olympic gold medal in what sport?", "How many days make up a non-leap year in the Islamic calendar?", "What scientist first determined that human sight results from images projected onto the retina?"]
        answer_A = ["A. Traveling salesman", "A. Australia", "A. Oh Lady! Lady!", "A. Baghdad",  "A. Have a panic attack",  "A. Nimptosical",  "A. Six iron",  "A. Swimming",  "A. 365 days",  "A. Galileo"]
        answer_B = ["B. Local sheriff", "B. The Netherlands", "B. Yip, Yip, Yaphank", "B. New Delhi", "B. Remember a name", "B. Buzzey", "B. Sand wedge", "B. Rowing", "B. 400 days", "B. Isaac Newton"]
        answer_C = ["C. His dentist", "C. The Philippines", "C. Blossom Time", "C. Cairo", "C. Get a joke", "C. Pifflicated", "C. Nine iron", "C. Fencing", "C. 376 days", "C. Copernicus"]
        answer_D = ["D. His butcher", "D. Turkey", "D. Watch your step", "D. Moscow", "D. Listen to music", "D. Staggerish", "D. Seven iron", "D. Sailing", "D. 354 days", "D. Johannes Kepler"]
        correct_4 = ["c", "c", "b", "a", "c", "c", "a", "b", "d", "d"]


        i = 0
        while (i == 0):

            if x == -1:
                x = randint(0, 9)
                print(f"""******************** FINAL ROUND ******************** 
                    This is the last question. If you answer well, you'll get the million dollar.
                    If you miss it, you go to {country} hands free. \n\n""")
                input("<Press any key to continue>")
            
            print(list_4[x] + "\n\t" + answer_A[x] + "\n\t" + answer_B[x] + "\n\t" + answer_C[x] + "\n\t" + answer_D[x] + "\n")
            answer = input("What is your answer ? \n\n")
            answer = answer.lower()

            if answer not in correct_4:
                print("\n Please answer by the LETTER associated with the question!!! \n \n")
                
            else:
                if answer == correct_4[x]:
                    print(f"""\n You provided a good answer !!!
                              Congratulations {host_name}!!! 
                              I can't believe it. The million is yours. Enjoy it !!!""")
                    score = 1000000
                    i = -1
                    replay()

                else:
                    fail(score)

    
    # Fail Function
#The argument 'score' helps to know at which round the user lose to customize the message.    
def fail(score):
    if score == 0:
        print(f"""\n This is not the right answer :'(. 
                  I'm sorry {host_name}, but you are unfortunately leaving the game at the first round.
                  But before going ...""")
        food = input("\n ... What's your favorite food?")
        food = food.capitalize()
        
        print(f""" \n\n It was {host_name}, whose favorite food is {food}. 
                   Thank you for your participation!""")
                
        # Replay 
        replay()

    elif score == 1000:
        print(f""" \n\n This is not the right answer :'(. 
                  I'm sorry {host_name}, but you are unfortunately leaving the game at the second round.
                  But before going ...""")
        food = input("What's your favorite food?")
        food = food.capitalize()
        
        print(f""" \n\n It was {host_name}, whose favorite food is {food}. 
                   Thank you for your participation!""")
        # Replay 
        replay()

    elif score == 10000:
        print(f"""\n\n This is not the right answer :'(. 
                  I'm sorry {host_name}, but you are unfortunately leaving the game at the third round.
                  But before going ...""")
        food = input("What's your favorite food?")
        food = food.capitalize()
        
        print(f""" \n\n It was {host_name}, whose favorite food is {food}. 
                   Thank you for your participation!""")
        # Replay 
        replay()

    elif score == 100000:     
        print(f"""\n\n This is not the right answer :'(. 
                  I'm sorry {host_name}, but you are unfortunately leaving the game at the final round.
                  You were so close to the million prize.
                  But before going ...""")
        food = input("What's your favorite food?")
        food = food.capitalize()
        
        print(f""" \n\n It was {host_name}, whose favorite food is {food}. 
                   Thank you for your participation!
                   Hope to see you next time.""")

        # Replay 
        replay()

# Replay Function: Ask to user if he/she wants to play again.       
        
def replay():
    print("\n Would you like to play again? (Yes/No)")    
    rep = input("> ")    
    rep = rep.lower()    

    if rep == "yes":
        round_1(-1)    
    elif rep == "no":
        print(f": \n Thanks for playing {host_name}!") 
        input("<Press any key to exit> \n")
        exit(0)
    else:
        print ("\n Please answer by 'Yes' or 'No'!!!")
        replay()
    

######### GAME START ##########
game_start()
# Out:
# Hello and welcome once to WHO WANT TO BE A MILLIONAIRE!!!
#
# <Press any key to continue>
#
# My name is Estelle and  I'm hosting today's Who wants to be a millionaire.
#
# So, how am I calling tonight ?
# peqce
# We welcome our contestant Peqce that will compete for the ultimate million dollar prize!
#               Thank you for joining us.
#               These are the rules of the game. In order to gain the prize, you need to reach 1,000,000 points
#               and answer four questions.
#               The first question gives you 1,000 points, the second 10,000 points, the third 100,000 and finally the last
#               and fourth question 1,000,000 points and the million dollar.
#
# <Press any key to continue
# Before starting, where are you coming from?indiq
#  Thank you very much.
#                A lot of applause for Peqce coming from Indiq !
#
# So What are your plans if you win the million dollar prize today ?
# >shopping
#
#  Waouh ! That's really nice.
# ...
